# %% [markdown]
# # import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # now some examples

# %%
x = np.random.normal(size=1000)
a = plt.hist(x)

# %%
df = pd.DataFrame( {'x':x, 'y': x + np.random.normal(size=1000)})
print(df.head())
# Out:
#           x         y
# 0  0.793284  0.400263
# 1  0.602367 -0.707347
# 2  0.715999  0.581231
# 3 -0.995538 -1.255675
# 4 -0.459823 -0.874597

# %%
a = plt.scatter(df.x, df.y, edgecolor='k')
