# %%
import pandas as pd

# %%
names = ['China', 'India', 'US']
pop = [1420, 1370, 329]
cap = ['Beijing', 'New Delhi', 'Washington, DC']
df = pd.DataFrame({'capital':cap, 'population':pop}, index=names)

# %%
df
# Out:
#               capital  population
# China         Beijing        1420
# India       New Delhi        1370
# US     Washington, DC         329

# %%
df.iloc[[1]]
# iloc --> row number based index
# loc --> row based index
# Out:
#          capital  population
# India  New Delhi        1370

# %%
df.iloc[:2, 1]
# Out:
# China    1420
# India    1370
# Name: population, dtype: int64

# %%
df.loc['India']
# Out:
# capital       New Delhi
# population         1370
# Name: India, dtype: object

# %%
df.loc['India', 'capital']
# Out:
# 'New Delhi'

# %%
df.loc[['India', 'US', 'China', 'India'], 'capital']
# Out:
# India         New Delhi
# US       Washington, DC
# China           Beijing
# India         New Delhi
# Name: capital, dtype: object

# %%
df.loc[:, 'capital']
# Out:
# China           Beijing
# India         New Delhi
# US       Washington, DC
# Name: capital, dtype: object

# %%
df['capital']
# Out:
# China           Beijing
# India         New Delhi
# US       Washington, DC
# Name: capital, dtype: object

# %%
df.capital
# Out:
# China           Beijing
# India         New Delhi
# US       Washington, DC
# Name: capital, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.random.normal(size=100)

# %%
y = np.random.normal(size=100)

# %%
plt.scatter(x, y)

# %%
plt.plot(x, y)

# %%
x = np.linspace(-5, 5, 50)
# sequence of numbers from -5 to 5, 50 numbers evenly spaced

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
plt.plot(x, y, linestyle = '--', c='red')

# %%
gsa = pd.read_csv('./GSAF5.csv.bz2', sep='\t')

# %%
gsa.shape
# Out:
# (25760, 24)

# %%
gsa.head(3)
# Out:
#   Case Number         Date    Year        Type Country     Area  \
# 0  2019.08.27  27-Aug-2019  2019.0    Provoked     USA  Florida
# 1  2019.08.21  21-Aug-2019  2019.0  Unprovoked     USA  Florida
# 2  2019.08.20  20-Aug-2019  2019.0  Unprovoked     USA   Hawaii
#
#                                           Location  Activity  \
# 0                 New Smyrna Beach, Volusia County   Surfing
# 1                  Fort Lauderdale, Broward County    Wading
# 2  Napoopoo Park in Kealakekua Bay, The Big Island  Swimming
#
#                  Name Sex   ...    Species            Investigator or Source  \
# 0        Donald Walsh    M  ...  6.5' shark  K. McMurray, TrackingSharks.com
# 1  Christian Mariani     M  ...         NaN  K. McMurray, TrackingSharks.com
# 2              female    F  ...         NaN       Hawaii News Now, 8/20/2019
#
#                       pdf                                       href formula  \
# ...

# %%
gsa.iloc[0]
# Out:
# Case Number                                                      2019.08.27
# Date                                                            27-Aug-2019
# Year                                                                   2019
# Type                                                               Provoked
# Country                                                                 USA
# Area                                                                Florida
# Location                                   New Smyrna Beach, Volusia County
# Activity                                                            Surfing
# Name                                                           Donald Walsh
# Sex                                                                       M
# Age                                                                      40
# Injury                    Hand and calf bitten when he jumped off surfbo...
# ...

# %%
gsa.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
gsa = gsa.drop('Name', axis=1)
# axis 1 tells it to drop a column, not a row

# %%
gsa.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
gsa1 = gsa[['Date', 'Country', 'Age', 'Fatal (Y/N)']]

# %%
gsa1.shape
# Out:
# (25760, 4)

# %%
gsa1.head()
# Out:
#           Date Country Age Fatal (Y/N)
# 0  27-Aug-2019     USA  40           N
# 1  21-Aug-2019     USA  11           N
# 2  20-Aug-2019     USA  26           N
# 3  16-Aug-2019     USA   9           N
# 4  11-Aug-2019     USA  16           N

# %%
gsa2 = gsa1.rename({'Fatal (Y/N)':'killed'}, axis=1)
# specify you're renaming a column

# %%
gsa2.head()
# Out:
#           Date Country Age killed
# 0  27-Aug-2019     USA  40      N
# 1  21-Aug-2019     USA  11      N
# 2  20-Aug-2019     USA  26      N
# 3  16-Aug-2019     USA   9      N
# 4  11-Aug-2019     USA  16      N

# %%
gsa2.groupby('Country').size()
# .count counts all non-missing observations
# Out:
# Country
#  PHILIPPINES          1
#  TONGA                3
# ADMIRALTY ISLANDS     1
# AFRICA                1
# ALGERIA               1
#                      ..
# VIETNAM              15
# WEST INDIES           2
# WESTERN SAMOA         1
# YEMEN                 2
# YEMEN                 7
# Length: 213, dtype: int64

# %%
gsa2['country'] = gsa2.Country.str.strip()

# %%
gsa2.groupby('country').size()
# Out:
# country
# ADMIRALTY ISLANDS              1
# AFRICA                         1
# ALGERIA                        1
# AMERICAN SAMOA                 3
# ANDAMAN / NICOBAR ISLANDAS     1
#                               ..
# VENEZUELA                     11
# VIETNAM                       15
# WEST INDIES                    2
# WESTERN SAMOA                  1
# YEMEN                          9
# Length: 205, dtype: int64

# %%
gsa2.country.head(10)
# Out:
# 0    USA
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# 6    USA
# 7    USA
# 8    USA
# 9    USA
# Name: country, dtype: object

# %%
gsa2.country.tail(10)
# Out:
# 25750    NaN
# 25751    NaN
# 25752    NaN
# 25753    NaN
# 25754    NaN
# 25755    NaN
# 25756    NaN
# 25757    NaN
# 25758    NaN
# 25759    NaN
# Name: country, dtype: object

# %%
gsa2.country.sample(10)
# Out:
# 4630     SOUTH AFRICA
# 465             ARUBA
# 21766             NaN
# 6249     SIERRA LEONE
# 9293              NaN
# 16056             NaN
# 6847              NaN
# 18247             NaN
# 8559              NaN
# 12481             NaN
# Name: country, dtype: object

# %%
gsa2.country.isnull().sum()
# Out:
# 19359

# %%
gsa2.country.value_counts()
# Out:
# USA                             2310
# AUSTRALIA                       1365
# SOUTH AFRICA                     583
# PAPUA NEW GUINEA                 134
# NEW ZEALAND                      133
#                                 ...
# EQUATORIAL GUINEA / CAMEROON       1
# MALDIVES                           1
# GREENLAND                          1
# JAVA                               1
# RED SEA?                           1
# Name: country, Length: 205, dtype: int64

# %%
gsa3 = gsa2[gsa2.country.isin(['USA', 'AUSTRALIA'])].copy()

# %%
gsa3.shape
# Out:
# (3675, 5)

# %%
gsa3.head(4)
# Out:
#           Date Country Age killed country
# 0  27-Aug-2019     USA  40      N     USA
# 1  21-Aug-2019     USA  11      N     USA
# 2  20-Aug-2019     USA  26      N     USA
# 3  16-Aug-2019     USA   9      N     USA

# %%
gsa3.Date.sample(10)
# Out:
# 2109    02-Apr-2001
# 887     02-Sep-2012
# 818     04-May-2013
# 4011    19-Dec-1961
# 2149    16-Sep-2000
# 3719    11-Jun-1966
# 3411    26-May-1974
# 2304    22-Sep-1998
# 4657    25-Jul-1949
# 474     07-Nov-2015
# Name: Date, dtype: object

# %%
gsa3.loc[6279]
# Out:
# Date        Mar-1803
# Country    AUSTRALIA
# Age              NaN
# killed             N
# country    AUSTRALIA
# Name: 6279, dtype: object

# %%
gsa3['year'] = gsa3.Date.str[-4:]

# %%
gsa3.year
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 6444    1906
# 6445    1906
# 6446    1903
# 6447    1903
# 6448    1905
# Name: year, Length: 3675, dtype: object
