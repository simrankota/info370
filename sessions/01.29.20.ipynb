# %%
import numpy as np

# %%
mn = 86220
md = 61710

# %%
hh = np.random.lognormal(np.log(md), np.sqrt(2*(np.log(mn) - np.log(md))), size=int(1e6))

# %%
len(hh)
# Out:
# 1000000

# %%
np.mean(hh)
# Out:
# 86219.03621663318

# %%
np.median(hh)
# Out:
# 61636.70044501376

# %%
np.random.choice(hh, 10)
# Out:
# array([67008.78971867, 48686.99762515, 34130.22845594, 78024.2139616 ,
#        50746.74527042, 20965.22859278, 32467.25370736, 82883.77039751,
#        72286.18160309, 25597.12135161])

# %%
np.mean(np.random.choice(hh, 1000))
# Out:
# 87901.92490152824

# %%
np.mean(np.random.choice(hh, 1000))
# Out:
# 84843.34077730263

# %%
np.mean(np.random.choice(hh, 1000))
# Out:
# 87962.65789657977

# %%
np.mean(np.random.choice(hh, 1000))
# Out:
# 85458.01630161813

# %%
import matplotlib.pyplot as plt

# %%
_ = plt.hist(hh, bins = 100)

# %%
np.mean(np.random.choice(hh, 1000))
# Out:
# 84445.20787551231

# %%
m = np.array([np.mean(np.random.choice(hh, 1000)) for i in range(1000)])

# %%
type(m)
# Out:
# numpy.ndarray

# %%
m[:30]
# Out:
# array([86477.92527099, 84989.95188443, 85012.56133475, 87224.27090041,
#        85352.70260384, 87887.17887533, 85454.03545531, 84095.74223713,
#        90275.90859971, 90876.67223175, 90913.33532593, 87183.00760337,
#        88193.48901073, 86189.39927023, 83960.18138928, 86783.83207771,
#        86753.2460166 , 84643.97011885, 86628.19145415, 82375.51243674,
#        86740.56430753, 86231.40760027, 86028.77630001, 87237.94118195,
#        88574.00798368, 84440.5307385 , 87943.07030111, 83974.88747915,
#        87491.13272912, 82768.64248242])

# %%
np.mean(m)
# Out:
# 86186.57712870375

# %%
_ = plt.hist(m, bins = 30)

# %%
np.quantile(m, 0.025)
# Out:
# 80953.58411217849

# %%
np.quantile(hh, 0.975)
# Out:
# 307373.8708771395

# %%
np.random.exponential(0.5, size=30)
# Out:
# array([1.91420972, 0.37813869, 0.07521685, 0.19491492, 0.70757399,
#        0.1571    , 1.26439906, 0.01004869, 0.18742098, 0.69794332,
#        0.051871  , 0.08627279, 0.8420841 , 0.04028278, 0.47127645,
#        0.1231127 , 0.52091074, 0.32625379, 1.06698022, 0.12645867,
#        0.20402013, 0.03520461, 0.83058877, 1.0397707 , 0.16867534,
#        0.17020632, 0.10500006, 0.0122384 , 0.36242041, 1.65773351])

# %%
plt.hist(np.random.exponential(0.5, size=3000), bins=40)
# Out:
# (array([554., 465., 395., 300., 261., 185., 178., 126.,  95.,  74.,  74.,
#          58.,  39.,  34.,  27.,  18.,  17.,  18.,  17.,   9.,  15.,  11.,
#           4.,   6.,   4.,   4.,   3.,   2.,   2.,   0.,   1.,   2.,   0.,
#           1.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([5.16291644e-05, 1.02160621e-01, 2.04269612e-01, 3.06378603e-01,
#         4.08487595e-01, 5.10596586e-01, 6.12705578e-01, 7.14814569e-01,
#         8.16923561e-01, 9.19032552e-01, 1.02114154e+00, 1.12325053e+00,
#         1.22535953e+00, 1.32746852e+00, 1.42957751e+00, 1.53168650e+00,
#         1.63379549e+00, 1.73590448e+00, 1.83801348e+00, 1.94012247e+00,
#         2.04223146e+00, 2.14434045e+00, 2.24644944e+00, 2.34855843e+00,
#         2.45066742e+00, 2.55277642e+00, 2.65488541e+00, 2.75699440e+00,
#         2.85910339e+00, 2.96121238e+00, 3.06332137e+00, 3.16543036e+00,
#         3.26753936e+00, 3.36964835e+00, 3.47175734e+00, 3.57386633e+00,
# ...

# %%
n = np.random.exponential(0.5, size=3000)
np.mean(np.random.choice(n, 1000))
# Out:
# 0.5151353471627219

# %%
avgs = np.array([np.mean(np.random.choice(n, 1000)) for i in range(1000)])

# %%
plt.hist(avgs, bins=40)
# Out:
# (array([ 1.,  0.,  0.,  1.,  4.,  3.,  3.,  8.,  7., 15., 12., 29., 32.,
#         36., 62., 61., 63., 91., 82., 70., 89., 56., 50., 46., 50., 33.,
#         24., 18., 18., 17.,  7.,  5.,  6.,  0.,  0.,  0.,  0.,  0.,  0.,
#          1.]),
#  array([0.44591571, 0.44888209, 0.45184848, 0.45481487, 0.45778126,
#         0.46074765, 0.46371403, 0.46668042, 0.46964681, 0.4726132 ,
#         0.47557958, 0.47854597, 0.48151236, 0.48447875, 0.48744513,
#         0.49041152, 0.49337791, 0.4963443 , 0.49931068, 0.50227707,
#         0.50524346, 0.50820985, 0.51117623, 0.51414262, 0.51710901,
#         0.5200754 , 0.52304178, 0.52600817, 0.52897456, 0.53194095,
#         0.53490733, 0.53787372, 0.54084011, 0.5438065 , 0.54677288,
#         0.54973927, 0.55270566, 0.55567205, 0.55863843, 0.56160482,
#         0.56457121]),
#  <a list of 40 Patch objects>)
