# %%
import pandas as pd

# %%
fatherson = pd.read_csv('./fatherson.csv.bz2', '\t')

# %%
mag_in = pd.read_csv('./mag-in-citations.csv.bz2')

# %%
fatherson.columns
# Out:
# Index(['fheight', 'sheight'], dtype='object')

# %%
mag_in.columns
# Out:
# Index(['paperId', 'citations'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
p1 = plt.hist(fatherson.sheight, bins=20)
plt.show()

# %%
p2 = plt.hist(mag_in.citations, bins=5)
plt.show()
